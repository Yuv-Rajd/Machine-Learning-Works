# %% [markdown]
# ## matplotlib exercise

# %%
# %matplotlib inline 
import matplotlib.pyplot as pt 
import pandas as pd
import numpy as np

# %%
pt.plot()
# Out:
# []

# %%
pt.plot([1,2,3,4,5]);

# %%
x=[1,2,3,4,5]
y=[11,22,33,44,55]
pt.plot(x,y);

# %%
#1st method 
fig=pt.figure()
ax=fig.add_subplot()
pt.show()

# %%
#2nd method 
fig= pt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
pt.show()

# %%
#3rd method 
fig,ax =pt.subplots()
ax.plot(x,y);

# %% [markdown]
# ## Matpltlib exaample workflow

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt 

x=[1,2,3,4]
y= [11,22,33,44]

fig,ax =plt.subplots(figsize=(10,10))

ax.plot(x,y)

ax.set(title="simple-plot",
      xlabel="x-label",
      ylabel="y-label")

fig.savefig("images/sample-plt-plot.png")

# %% [markdown]
# ## making figure with Numpy arrays

# %%
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig,ax = plt.subplots()
ax.plot(x,x**2);

# %%
#scatter plot 
fig,ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %%
#anothe rscatter plot 
fig, ax =plt.subplots()
ax.scatter(x,np.sin(x));

# %%
#make a plot fromm dictionarry
nut_butter_price= {"almond butter ":10,
                  "Penut butter ":8,
                  "Casew butter ":12}
fig, ax = plt.subplots()
ax.bar(nut_butter_price.keys(),nut_butter_price.values())
ax.set(title="Nut Butter Price ",ylabel="price");

# %%
fig , ax =plt.subplots()
ax.barh(list(nut_butter_price.keys()),list(nut_butter_price.values()));

# %%
#make some data
x = np.random.randn(1000)
fig,ax =plt.subplots()
ax.hist(x);

# %% [markdown]
# ## two option for subplots

# %%
#opt 1
fig,((ax1,ax2),(ax3,ax4))= plt.subplots(nrows=2,
                                       ncols=2,figsize=(10,5))

#plot to all axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_price.keys(),nut_butter_price.values());
ax4.hist(np.random.randn(1000));

# %%
#option 2
fig,ax =plt.subplots(nrows=2,
                    ncols=2,
                    figsize=(10,5))

#plot to eachdifferent index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_price.keys(),nut_butter_price.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# # plotting from pandas dataframe

# %%
import pandas as pd

# %%
car_sales =pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
# C:\Users\yuvar\AppData\Local\Temp\ipykernel_3916\4215731511.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["sale Date"] = pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
#lets plot total sales 
car_sales.plot(x="sale Date",y="Total sales");

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
x= np.random.rand(10,4)

df =pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.325831  0.897641  0.078229  0.760157
# 1  0.420964  0.443138  0.368131  0.479159
# 2  0.575179  0.792274  0.115630  0.802891
# 3  0.443702  0.458202  0.759449  0.666885
# 4  0.639616  0.334827  0.823608  0.163225
# 5  0.239593  0.491309  0.070451  0.371529
# 6  0.122087  0.048475  0.063362  0.055891
# 7  0.228698  0.897294  0.962732  0.164341
# 8  0.364211  0.556117  0.334494  0.576185
# 9  0.840756  0.377169  0.029195  0.348167

# %%
df.plot.bar();

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
heart_diseas= pd.read_csv("heart-disease.csv")
heart_diseas.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_diseas[heart_diseas["age"] >50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#pyplot method
over_50.plot(kind='scatter',
            x='age',
            y='chol',
            c='target');

# %%
#oo method 
fix,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',
            x='age',
            y='chol',
             c='target',
            ax=ax);
# ax.set_xlim([45,100])

# %%
fig,(ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10))

scatter =ax0.scatter(x=over_50["age"],
                     y=over_50['chol'],
                     c=over_50["target"])

ax0.set(title="Heart Diseas and Cholstrol Lvele",
       xlabel="Age",
       ylabel="Choleserol")

ax0.legend(*scatter.legend_elements(),title="Terget")
ax0.axhline(y=over_50["chol"].mean(),linestyle="--");

scatter =ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"])
ax1.set(title="Heart Diseas and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate");
ax1.legend(*scatter.legend_elements(),title="Target")

ax1.axhline(y=over_50["thalach"].mean(),linestyle="--");

fig.suptitle("Heart Diseas Analysis",fontsize=16,fontweight='bold');

# %%
db = pd.read_csv("diabetes.csv")
db.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
over_20 = db[db["Age"]>20]
over_20
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
below_30 = db[db["Age"]<30]
below_30
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1       89             66             23       94  28.1
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 20             3      126             88             41      235  39.3
# 23             9      119             80             35        0  29.0
# ..           ...      ...            ...            ...      ...   ...
# 753            0      181             88             44      510  43.3
# 758            1      106             76              0        0  37.5
# 760            2       88             58             26       16  28.4
# 764            2      122             70             27        0  36.8
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %%
outcome_1 =db[db["Outcome"]==1]
outcome_1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
below_30_and_1 = db[db["A and "Outcome"==1]]
below_30_and_1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 below_30_and_1 = db[db["Age" < 30 and "Outcome"==1]]
#       2 below_30_and_1
#
# TypeError: '<' not supported between instances of 'str' and 'int'
